# %% [markdown]
# <a href="https://colab.research.google.com/github/bnnguyen/AUTOMATIC_PRIME_FACTORIZATION/blob/main/Deslab_2024_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cách trực quan hóa dữ liệu - Project mẫu về dữ liệu người chơi bóng rổ

# %%
# imports for data processing and analytics
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

# imports for data visualization
import matplotlib.pyplot as plt
import seaborn as sns # library for more advanced plots
import plotly.express as px # library for interactive plots
# %matplotlib inline
# makes graphs inline, always useful to put when using matplotlib

# %% [markdown]
# ## Phân tích và trực quan hóa dữ liệu (sử dụng Matplotlib và Seaborn)

# %%
data_url = "https://raw.githubusercontent.com/arjun-prabhakar/crimson-data-science/main/NBAplayerTotals2020.csv"
basketballData = pd.read_csv(data_url)
basketballData.head()
# Out:
#                      Player Pos   Age   Tm     G    GS      MP     FG    FGA  \
# 0              Steven Adams   C  26.0  OKC  63.0  63.0  1680.0  283.0  478.0
# 1               Bam Adebayo  PF  22.0  MIA  72.0  72.0  2417.0  440.0  790.0
# 2         LaMarcus Aldridge   C  34.0  SAS  53.0  53.0  1754.0  391.0  793.0
# 3            Kyle Alexander   C  23.0  MIA   2.0   0.0    13.0    1.0    2.0
# 4  Nickeil Alexander-Walker  SG  21.0  NOP  47.0   1.0   591.0   98.0  266.0
#
#      FG%    3P    3PA    3P%     2P    2PA    2P%    eFG     FT    FTA    FT%  \
# 0  0.592   1.0    3.0  0.333  282.0  475.0  0.594  0.593  117.0  201.0  0.582
# 1  0.557   2.0   14.0  0.143  438.0  776.0  0.564  0.558  264.0  382.0  0.691
# 2  0.493  61.0  157.0  0.389  330.0  636.0  0.519  0.532  158.0  191.0  0.827
# 3  0.500   0.0    0.0  0.000    1.0    2.0  0.500  0.500    0.0    0.0  0.000
# 4  0.368  46.0  133.0  0.346   52.0  133.0  0.391  0.455   25.0   37.0  0.676
#
#      ORB    DRB    TRB    AST   STL   BLK    TOV     PF     PTS   TS%    PER  \
# 0  207.0  376.0  583.0  146.0  51.0  67.0   94.0  122.0   684.0  0.60  19.02
# 1  176.0  559.0  735.0  368.0  82.0  93.0  204.0  182.0  1146.0  0.60  18.06
# 2  103.0  289.0  392.0  129.0  36.0  87.0   74.0  128.0  1001.0  0.57  18.39
# 3    2.0    1.0    3.0    0.0   0.0   0.0    1.0    1.0     2.0  0.50   5.29
# 4    9.0   75.0   84.0   89.0  17.0   8.0   54.0   57.0   267.0  0.47   9.91
#
#        VA  EWA
# 0  211.13  7.0
# 1  236.65  7.9
# 2  203.94  6.8
# 3   -1.03 -0.0
# 4   -5.20 -0.2

# %% [markdown]
# ### Player Efficiency Rating (PER)

# %% [markdown]
# Tạo một biểu đồ thanh có 20 người chơi hàng đầu về PER trên trục x và PER tương ứng của họ trên trục y bằng Matplotlib (xem ví dụ sử dụng Seaborn bên dưới)

# %%
#Modified DF
sortedPER = basketballData.sort_values(['PER'], ascending=False)
PERtop20 = sortedPER.head(20)

# %%
#Matplotlib Pyplot
plt.figure(figsize=(30, 10))
plt.bar(PERtop20['Player'], PERtop20['PER'])
plt.xlabel('Player')
plt.ylabel('Player Efficiency Rating (PER)')
plt.title('Top 20 Players in the NBA by PER')
plt.xticks(rotation=30, ha='center')
plt.show()

# %%
#Example in Seaborn with Matplotlib
fig, ax = plt.subplots(figsize=(7, 10))
plt.title('Top 20 Players in NBA by PER')
sns.set_color_codes("pastel")
sns.barplot(x="PER", y="Player", data=PERtop20, color="g")
# Out:
# <Axes: title={'center': 'Top 20 Players in NBA by PER'}, xlabel='PER', ylabel='Player'>

# %% [markdown]
# Bây giờ sắp xếp dữ liệu theo cột VA theo thứ tự giảm dần và lấy 20 VA hàng đầu. Sử dụng công cụ này để vẽ biểu đồ EWA cho phép chúng ta có được 20 cầu thủ hàng đầu tại NBA theo EWA.

# %%
# Sort based on VA and get the first 20 rows from this sorted dataframe
sortedVA = basketballData.sort_values(['VA'], ascending=False)
VAtop20 = sortedVA.head(20)
#MatPlotLib Pyplot
plt.figure(figsize=(30, 10))
plt.bar(VAtop20['Player'], VAtop20['EWA'])
plt.xlabel('Player')
plt.ylabel('Estimated Wins Added (EWA)')
plt.title('Top 20 Players in the NBA by EWA')
plt.xticks(rotation=30, ha='center')
plt.show()

# %%
#Example of bar plot with the help of Seaborn
fig, ax = plt.subplots(figsize=(7, 10))
plt.title('Top 20 Players in NBA by EWA')
sns.set_color_codes("pastel")
sns.barplot(x="EWA", y="Player", data=VAtop20, color="g")
# Out:
# <Axes: title={'center': 'Top 20 Players in NBA by EWA'}, xlabel='EWA', ylabel='Player'>

# %%
#Now plot the bottom 20 players using Seaborn with Matplotlib (really similar to the previous cell)
VAbottom20 = sortedVA.tail(20)
VAbottom20 = VAbottom20.sort_values(by = 'EWA', ascending=True)

# Uncomment the code below after specifying the bottom 20 players above this line
fig, ax = plt.subplots(figsize=(7, 10))
plt.title('Bottom 20 Players in NBA by EWA')
sns.set_color_codes("pastel")
sns.barplot(x="EWA", y="Player", data=VAbottom20, color="r")
# Out:
# <Axes: title={'center': 'Bottom 20 Players in NBA by EWA'}, xlabel='EWA', ylabel='Player'>

# %%
# Looking at a Pair Plot
basic_stats = ['Pos','PTS', 'AST', 'TRB', 'STL', 'BLK']
sns.set_color_codes("pastel")
sns.set(style="ticks", color_codes=True)
sns.set_style('darkgrid')
sns.pairplot(basketballData[basic_stats], hue = 'Pos', palette = 'husl')

# %% [markdown]
# ## Tạo biểu đồ trực quan tương tác được với Plotly

# %%
#Another graphing library is Plotly which we can use for interactive graphs
fig = px.scatter(basketballData, x='PTS', y='AST', hover_data = ['Player'])
fig.update_layout(title_text = 'Points vs. Assists for 2020 NBA Players')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="84e243df-2f84-467e-b3bf-4befbf834dd2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
Kris Dunn"],["Carsen Edwards"],["Henry Ellenson"],["Wayne Ellington"],["Joel Embiid"],["James Ennis III"],["Drew Eubanks"],["Jacob Evans"],["Dante Exum"],["Tacko Fall"],["Derrick Favors"],["Cristiano Fel\u00edcio"],["Terrance Ferguson"],["Bruno Fernando"],["Yogi Ferrell"],["Dorian Finney-Smith"],["Bryn Forbes"],["Evan Fournier"],["De'Aaron Fox"],["Melvin Frazier"],["Michael Frazier"],["Tim Frazier"],["Enes Freedom"],["Markelle Fultz"],["Wenyen Gabriel"],["Daniel Gafford"],["Danilo Gallinari"],["Langston Galloway"],["Darius Garland"],["Marc Gasol"],["Rudy Gay"],["Paul George"],["Taj Gibson"],["Harry Giles"],["Shai Gilgeous-Alexander"],["Rudy Gobert"],["Brandon Goodwin"],["Aaron Gordon"],["Eric Gordon"],["Devonte' Graham"],["Treveon Graham"],["Jerami Grant"],["Jerian Grant"],["Josh Gray"] ...

# %%
#Using Pyplot, create a scatterplot that shows the FG percentage versus the Estimated Wins Added for 2020 NBA Players
fig = px.scatter(basketballData, x='EWA', y='FG%', hover_data = ['Player', 'Pos'], color='3P%', color_continuous_scale='viridis')
fig.update_layout(title_text = 'Field Goals % vs. Estimated Wins Added for 2020 NBA Players')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5e45e089-704c-4d14-9b0a-0f9a8070ec60" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e45e089-704c-4d14-9b0a-0f9a8070ec60")) {                    Plotly.newPlot(                        "5e45e089-704c-4d14-9b0a-0f9a8070ec60",                        [{"customdata":[["Steven Adams","C"],["Bam Adebayo","PF"],["LaMarcus Aldridge","C"],["Kyle Alexander","C"],["Nickeil Alexander-Walker","SG"],["Grayson Allen","SG"],["Jarrett Allen","C"],["Kadeem Allen","PG"],["Al-Farouq Aminu","PF"],["Justin Anderson","SG"],["Kyle Anderson","SF"],["Ryan Anderson","C"],["Giannis Antetokounmpo","PF"],["Kostas Antetokounmpo","PF"],["Thanasis Antetokounmpo","SF"],["Carmelo Anthony","PF"],["OG Anunoby","SF"],["Ryan Arcidiacono","PG"],["Trevor Ariza","SF"],["D.J. Augustin","PG"],["Deandre Ayton","C"],["Dwayne Bacon","SG"],["Marvin Bagley III","C"],["Lonzo Ball","PG"],["Mo Bamba","C"],["J.J. Barea","PG"],["Harrison Barnes","PF"],["RJ Barrett","SG"],["Will Barton","SF"],["Keita Bates-Diop","SF"],["Nicolas Batum","SF"],["Aron Baynes","C"],["Kent Bazemore","SF"],["Darius Bazley","PF"],["Bradley Beal","SG"],["Malik Beasley","SG"],["Marco Belinelli","SG"],["Jordan Bell","C"],["DeAndre' Bembry","SG"],["Dragan Bender","PF"],["D\u0101vis Bert\u0101ns","PF"],["Patrick Beverley","PG"],["Khem Birch","C"],["Goga Bitadze","C"],["Bismack Biyombo","C"],["Nemanja Bjelica","PF"],["Eric Bledsoe","PG"],["Bogdan Bogdanovi\u0107","SG"],["Bojan Bogdanovi\u0107","SF"],["Bol Bol","PF"],["Jonah Bolden","C"],["Marques Bolden","C"],["Jordan Bone","PG"],["Isaac Bonga","SF"],["Devin Booker","SG"],["Chris Boucher","C"],["Brian Bowen","SF"],["Ky Bowman","PG"],["Avery Bradley","SG"],["Tony Bradley","C"],["Jarrell Brantley","PF"],["Ignas Brazdeikis","SF"],["Corey Brewer","PF"],["Mikal Bridges","SF"],["Miles Bridges","SF"],["Oshae Brissett","SF"],["Ryan Broekhoff","SF"],["Malcolm Brogdon","PG"],["Dillon Brooks","SG"],["Bruce Brown","PG"],["Charlie Brown Jr.","SG"],["Jaylen Brown","SG"],["Moses Brown","C"],["Sterling Brown","SF"],["Troy Brown Jr.","SF"],["Jalen Brunson","PG"],["Thomas Bryant","C"],["Reggie Bullock","SG"],["Trey Burke","PG"],["Alec Burks","SG"],["Deonte Burton","SF"],["Jimmy Butler","SF"],["Bruno Caboclo","C"],["Devontae Cacok","C"],["Kentavious Caldwell-Pope","SG"],["Vlatko \u010can\u010dar","PF"],["Clint Capela","C"],["DeMarre Carroll","C"],["Jevon Carter","PG"],["Vince Carter","PF"],["Wendell Carter Jr.","C"],["Michael Carter-Williams","SG"],["Alex Caruso","PG"],["Willie Cauley-Stein","C"],["Tyson Chandler","C"],["Wilson Chandler","PF"],["Joe Chealey","PG"],["Zylan Cheatham","PF"],["Chris Chiozza","PG"],["Marquese Chriss","PF"],["Gary Clark","SF"],["Brandon Clarke","PF"],["Jordan Clarkson","SG"],["Nic Claxton","C"],["Chris Clemons","SG"],["Antonius Cleveland","SG"],["Amir Coffey","SG"],["John Collins","PF"],["Zach Collins","PF"],["Mike Conley","PG"],["Pat Connaughton","SG"],["Quinn Cook","PG"],["Tyler Cook","SF"],["Robert Covington","C"],["Allen Crabbe","SF"],["Torrey Craig","SF"],["Jamal Crawford","SG"],["Jae Crowder","PF"],["Jarrett Culver","SG"],["Seth Curry","SG"],["Stephen Curry","PG"],["Troy Daniels","SG"],["Anthony Davis","PF"],["Ed Davis","C"],["Terence Davis","SG"],["Dewayne Dedmon","C"],["Matthew Dellavedova","PG"],["DeMar DeRozan","SF"],["Cheick Diallo","C"],["Hamidou Diallo","SF"],["Gorgui Dieng","C"],["Spencer Dinwiddie","PG"],["Donte DiVincenzo","SG"],["Luka Don\u010di\u0107","PG"],["Luguentz Dort","SF"],["Damyean Dotson","SG"],["Sekou Doumbouya","PF"],["PJ Dozier","SG"],["Goran Dragi\u0107","PG"],["Andre Drummond","C"],["Jared Dudley","PF"],["Kris Dunn","PG"],["Carsen Edwards","SG"],["Henry Ellenson","C"],["Wayne Ellington","SG"],["Joel Embiid","C"],["James Ennis II ...

# %%
#Using Pyplot, now create a scatterplot that shows the Personal Fouls versus the Total Points for 2020 NBA Players
fig = px.scatter(basketballData, x='PF', y='PTS', hover_data = ['Player', 'Pos'], color='EWA', color_continuous_scale='viridis')
fig.update_layout(title_text = 'Personal Fouls vs. Total Points for 2020 NBA Players')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c9de26c2-cf72-4bba-bac4-943d0a234c3c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c
an Clarkson","SG"],["Nic Claxton","C"],["Chris Clemons","SG"],["Antonius Cleveland","SG"],["Amir Coffey","SG"],["John Collins","PF"],["Zach Collins","PF"],["Mike Conley","PG"],["Pat Connaughton","SG"],["Quinn Cook","PG"],["Tyler Cook","SF"],["Robert Covington","C"],["Allen Crabbe","SF"],["Torrey Craig","SF"],["Jamal Crawford","SG"],["Jae Crowder","PF"],["Jarrett Culver","SG"],["Seth Curry","SG"],["Stephen Curry","PG"],["Troy Daniels","SG"],["Anthony Davis","PF"],["Ed Davis","C"],["Terence Davis","SG"],["Dewayne Dedmon","C"],["Matthew Dellavedova","PG"],["DeMar DeRozan","SF"],["Cheick Diallo","C"],["Hamidou Diallo","SF"],["Gorgui Dieng","C"],["Spencer Dinwiddie","PG"],["Donte DiVincenzo","SG"],["Luka Don\u010di\u0107","PG"],["Luguentz Dort","SF"],["Damyean Dotson","SG"],["Sekou Doumbouya","PF"],["PJ Dozier","SG"],["Goran Dragi\u0107","PG"],["Andre Drummond","C"],["Jared Dudley","PF"],["Kris Dunn","PG"],["Carsen Edwards","SG"],["Henry Ellenson","C"],["Wayne Ellington","SG"],["Joel Embiid","C"],["James Ennis II ...

# %%
fig = px.scatter_matrix(basketballData, dimensions=["PTS", "TRB", "AST"], title="2020 NBA Players", hover_data = ['Player'], color='Pos')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="14d0891e-887d-4fcc-8b8a-fa0cd401aba4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14d0891e-887d-4fcc-8b8a-fa0cd401aba4")) {                    Plotly.newPlot(                        "14d0891e-887d-4fcc-8b8a-fa0cd401aba4",                        [{"customdata":[["Steven Adams"],["LaMarcus Aldridge"],["Kyle Alexander"],["Jarrett Allen"],["Ryan Anderson"],["Deandre Ayton"],["Marvin Bagley III"],["Mo Bamba"],["Aron Baynes"],["Jordan Bell"],["Khem Birch"],["Goga Bitadze"],["Bismack Biyombo"],["Jonah Bolden"],["Marques Bolden"],["Chris Boucher"],["Tony Bradley"],["Moses Brown"],["Thomas Bryant"],["Bruno Caboclo"],["Devontae Cacok"],["Clint Capela"],["DeMarre Carroll"],["Wendell Carter Jr."],["Willie Cauley-Stein"],["Tyson Chandler"],["Nic Claxton"],["Robert Covington"],["Ed Davis"],["Dewayne Dedmon"],["Cheick Diallo"],["Gorgui Dieng"],["Andre Drummond"],["Henry Ellenson"],["Joel Embiid"],["Drew Eubanks"],["Tacko Fall"],["Derrick Favors"],["Cristiano Fel\u00edcio"],["Bruno Fernando"],["Enes Freedom"],["Daniel Gafford"],["Marc Gasol"],["Taj Gibson"],["Harry Giles"],["Rudy Gobert"],["Jeff Green"],["Donta Hall"],["Montrezl Harrell"],["Isaiah Hartenstein"],["Udonis Haslem"],["Jaxson Hayes"],["John Henson"],["Dewan Hernandez"],["Willy Hernang\u00f3mez"],["Richaun Holmes"],["Al Horford"],["Dwight Howard"],["Serge Ibaka"],["Jaren Jackson Jr."],["James Johnson"],["Nikola Joki\u0107"],["Damian Jones"],["DeAndre Jordan"],["Mfiondu Kabengele"],["